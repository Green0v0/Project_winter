# %%
import pandas as pd
import numpy as np

# %%
# csv1 = pd.read_csv('../data/폐교정보.csv',encoding='cp949')
# csv2 = pd.read_csv('../data/노인인구.csv',encoding='cp949')
# csv3 = pd.read_csv('../data/도시별지방지표.csv',encoding='cp949')

# %%
data1 = pd.read_csv('../data/노인복지요약/cp949/노인복지요약1.csv', encoding='cp949')

# %%
# data1.drop(['Unnamed: 15', 'Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20','Unnamed: 21'], axis='columns', inplace=True)

# %%
data1
# Out:
#                양로원 Unnamed: 1     Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0               일련      시?군?구          시 설 명        시설장    입 소 현 황        NaN
# 1               번호        NaN            NaN        NaN         정원         현원
# 2              NaN        NaN            NaN        NaN        NaN          계
# 3               합계        NaN           12개소        NaN      1,286        965
# 4              NaN        NaN            NaN        NaN        NaN        NaN
# 5                1        종로구          청운양로원        이종명         57         52
# 6              NaN        NaN            NaN        NaN        NaN        NaN
# 7                2        광진구  THECLASSIC500        정동기        760        572
# 8              NaN        NaN            NaN        NaN        NaN        NaN
# 9                3        도봉구       자애로운성모의집        이명숙         26         22
# 10             NaN        NaN            NaN        NaN        NaN        NaN
# ...

# %%
data1 = data1.dropna(subset = ['양로원'])

# %%
data1
# Out:
#                양로원 Unnamed: 1     Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0               일련      시?군?구          시 설 명        시설장    입 소 현 황        NaN
# 1               번호        NaN            NaN        NaN         정원         현원
# 3               합계        NaN           12개소        NaN      1,286        965
# 5                1        종로구          청운양로원        이종명         57         52
# 7                2        광진구  THECLASSIC500        정동기        760        572
# 9                3        도봉구       자애로운성모의집        이명숙         26         22
# 11               4        노원구        시립수락양로원        김경란         80         62
# 13               5        노원구          홍파양로원        김우리         44         26
# 15               6        은평구            성우회        남상미         25         20
# 17               7        양천구        실버하우스늘봄        김선숙         41          0
# 19               8        강서구          쟌쥬강의집      페르난데스         25         24
# ...

# %%
data1 = data1.dropna(subset = ['Unnamed: 1'])

# %%
data2 = pd.read_csv('../data/노인복지요약/cp949/노인복지요약2.csv', encoding='cp949')
data3 = pd.read_csv('../data/노인복지요약/cp949/노인복지요약3.csv', encoding='cp949')
data4 = pd.read_csv('../data/노인복지요약/cp949/노인복지요약4.csv', encoding='cp949')
data5 = pd.read_csv('../data/노인복지요약/cp949/노인복지요약5.csv', encoding='cp949')
data6 = pd.read_csv('../data/노인복지요약/cp949/노인복지요약6.csv', encoding='cp949')

# %%
data2 = data2.dropna(subset = ['Unnamed: 1'])
data3 = data3.dropna(subset = ['Unnamed: 1'])
data4 = data4.dropna(subset = ['Unnamed: 1'])
data5 = data5.dropna(subset = ['Unnamed: 1'])
data6 = data6.dropna(subset = ['Unnamed: 1'])

# %%
data5['Unnamed: 4'] = data5['Unnamed: 4'].str.replace(pat=r'[?]', repl= r' ', regex=True)
data5['Unnamed: 5'] = data5['Unnamed: 5'].str.replace(pat=r'[?]', repl= r' ', regex=True)

# %%
data5['Unnamed: 6'] = data5['Unnamed: 6'].str.replace(pat=r'[?]', repl= r' ', regex=True)
data5['Unnamed: 7'] = data5['Unnamed: 7'].str.replace(pat=r'[?]', repl= r' ', regex=True)
data5['Unnamed: 8'] = data5['Unnamed: 8'].str.replace(pat=r'[?]', repl= r' ', regex=True)
data5['Unnamed: 9'] = data5['Unnamed: 9'].str.replace(pat=r'[?]', repl= r' ', regex=True)
data5['Unnamed: 10'] = data5['Unnamed: 10'].str.replace(pat=r'[?]', repl= r' ', regex=True)
data5['Unnamed: 11'] = data5['Unnamed: 11'].str.replace(pat=r'[?]', repl= r' ', regex=True)
data5['Unnamed: 12'] = data5['Unnamed: 12'].str.replace(pat=r'[?]', repl= r' ', regex=True)

# %%
data5['Unnamed: 13'] = data5['Unnamed: 13'].str.replace(pat=r'[?]', repl= r' ', regex=True)

# %%
data5
# Out:
#      2. 주?야간보호서비스 Unnamed: 1              Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 4              일련      시?군?구                   시 설 명        시설장    이 용 인 원
# 8               1        종로구                종로데이케어센터        이재원        17
# 10              2        종로구                청운실버데이케어        김기선        20
# 12              3        종로구                보현데이케어센터        양유진        20
# 14              4        종로구             혜화동성당데이케어센터        추교천        21
# 16              5        종로구     엠더블유 요양원 병설 주야간보호센터        최종심        11
# 18              6         중구                남산실버복지센터        박창남        32
# 20              7         중구                신당데이케어센터        김영태        42
# 22              8         중구             신당동성당데이케어센터        홍민정        21
# 24              9         중구                인애데이케어센터        임옥남        27
# 26             10         중구           구립중림어르신데이케어센터        김미현        20
# 28             11        용산구                용산데이케어센터        이성희        21
# ...

# %%
data4['Unnamed: 4'] = data4['Unnamed: 4'].str.replace(pat=r'[?]', repl= r' ', regex=True)
data4['Unnamed: 5'] = data4['Unnamed: 5'].str.replace(pat=r'[?]', repl= r' ', regex=True)
data4['Unnamed: 6'] = data4['Unnamed: 6'].str.replace(pat=r'[?]', repl= r' ', regex=True)
data4['Unnamed: 7'] = data4['Unnamed: 7'].str.replace(pat=r'[?]', repl= r' ', regex=True)
data4['Unnamed: 8'] = data4['Unnamed: 8'].str.replace(pat=r'[?]', repl= r' ', regex=True)
data4['Unnamed: 9'] = data4['Unnamed: 9'].str.replace(pat=r'[?]', repl= r' ', regex=True)
data4['Unnamed: 10'] = data4['Unnamed: 10'].str.replace(pat=r'[?]', repl= r' ', regex=True)
data4['Unnamed: 11'] = data4['Unnamed: 11'].str.replace(pat=r'[?]', repl= r' ', regex=True)
data4['Unnamed: 12'] = data4['Unnamed: 12'].str.replace(pat=r'[?]', repl= r' ', regex=True)
data4['Unnamed: 13'] = data4['Unnamed: 13'].str.replace(pat=r'[?]', repl= r' ', regex=True)

# %%
data4
# Out:
#      1. 방문요양서비스 Unnamed: 1        Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 4            일련      시?군?구             시 설 명        시설장    이 용 인 원        NaN
# 8             1        종로구      우리모두재가노인지원센터        현중식         0         12
# 10            2         중구        효도본부노인복지센터        김응종         0          0
# 12            3        용산구        용산재가노인지원센터        권용자         0         39
# 14            4        성동구          다정노인복지센터        성준경         0          0
# 16            5        성동구         (주)비전돌봄센터        유명옥         0         57
# 18            6        성동구       금호무지개노인복지센터        이소정         0         48
# 20            7        광진구          광진노인보호센터        조철행         0          0
# 22            8        광진구         아차산노인복지센터        박정섭         0          1
# 24            9        광진구        서울인애노인복지센터        김선옥         0          0
# 26           10        광진구         광진어르신복지센터        오병지         0         19
# ...

# %%
data6['Unnamed: 4'] = data6['Unnamed: 4'].str.replace(pat=r'[?]', repl= r' ', regex=True)
data6['Unnamed: 5'] = data6['Unnamed: 5'].str.replace(pat=r'[?]', repl= r' ', regex=True)
data6['Unnamed: 6'] = data6['Unnamed: 6'].str.replace(pat=r'[?]', repl= r' ', regex=True)
data6['Unnamed: 7'] = data6['Unnamed: 7'].str.replace(pat=r'[?]', repl= r' ', regex=True)
data6['Unnamed: 8'] = data6['Unnamed: 8'].str.replace(pat=r'[?]', repl= r' ', regex=True)
data6['Unnamed: 9'] = data6['Unnamed: 9'].str.replace(pat=r'[?]', repl= r' ', regex=True)
data6['Unnamed: 10'] = data6['Unnamed: 10'].str.replace(pat=r'[?]', repl= r' ', regex=True)
data6['Unnamed: 11'] = data6['Unnamed: 11'].str.replace(pat=r'[?]', repl= r' ', regex=True)
data6['Unnamed: 12'] = data6['Unnamed: 12'].str.replace(pat=r'[?]', repl= r' ', regex=True)
data6['Unnamed: 13'] = data6['Unnamed: 13'].str.replace(pat=r'[?]', repl= r' ', regex=True)

# %%
data6
# Out:
#      4. 방문목욕서비스 Unnamed: 1                Unnamed: 2    Unnamed: 3 Unnamed: 4  \
# 4            일련      시?군?구                     시 설 명           시설장    이 용 인 원
# 8             1         중구                  효도본부노인복지           김응종         0
# 10            2        용산구                  용산재가노인지원           권용자         0
# 12            3        성동구                 동서울노인복지센터           최광자         0
# 14            4        성동구                  다정노인복지센터           성준경         0
# 16            5        성동구                 (주)비전돌봄센터           유명옥         0
# 18            6        성동구               금호무지개노인복지센터           이소정         0
# 20            7        광진구                 아차산노인복지센터           박정섭         0
# 22            8        광진구                  서울인애노인복지           김선옥         0
# 24            9        광진구                 광진어르신복지센터           오병지         0
# 26           10        광진구                  열린재가노인지원           김창현         0
# ...

# %%
data6['Unnamed: 1'] = data6['Unnamed: 1'].str.replace(pat=r'[?]', repl= r' ', regex=True)
data5['Unnamed: 1'] = data5['Unnamed: 1'].str.replace(pat=r'[?]', repl= r' ', regex=True)
data4['Unnamed: 1'] = data4['Unnamed: 1'].str.replace(pat=r'[?]', repl= r' ', regex=True)
data3['Unnamed: 1'] = data3['Unnamed: 1'].str.replace(pat=r'[?]', repl= r' ', regex=True)
data2['Unnamed: 1'] = data2['Unnamed: 1'].str.replace(pat=r'[?]', repl= r' ', regex=True)
data1['Unnamed: 1'] = data1['Unnamed: 1'].str.replace(pat=r'[?]', repl= r' ', regex=True)
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data1
# Out:
#      양로원 Unnamed: 1           Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0     일련      시 군 구                시 설 명        시설장    입 소 현 황        NaN
# 5      1        종로구                청운양로원        이종명         57         52
# 7      2        광진구        THECLASSIC500        정동기        760        572
# 9      3        도봉구             자애로운성모의집        이명숙         26         22
# 11     4        노원구              시립수락양로원        김경란         80         62
# 13     5        노원구                홍파양로원        김우리         44         26
# 15     6        은평구                  성우회        남상미         25         20
# 17     7        양천구              실버하우스늘봄        김선숙         41          0
# 19     8        강서구                쟌쥬강의집      페르난데스         25         24
# 21     9        송파구               은빛천사의집        권혁근         12          7
# 23    10        금천구                혜명양로원        박혜정         64         57
# 25    11        금천구                 섭리의집        박정희         28         27
# ...

# %%
# data2.drop(['Unnamed: 15', 'Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20'], axis='columns', inplace=True)

# %%
# data3.drop(['Unnamed: 11','Unnamed: 12','Unnamed: 13','Unnamed: 14','Unnamed: 15', 'Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20'], axis='columns', inplace=True)
# data3.dropna(axis = 0,how = 'all')

# %%
# data4.dropna(axis = 0,how = 'all')

# %%
# data = pd.concat([data1,data2,data3,data4,data5,data6])

# %%
data1.to_csv(r'C:\Users\GREEN\data\total\data1.csv', sep=',',encoding='cp949',index=False)

# %%
data2.to_csv(r'C:\Users\GREEN\data\total\data2.csv', sep=',',encoding='cp949',index=False)
data3.to_csv(r'C:\Users\GREEN\data\total\data3.csv', sep=',',encoding='cp949',index=False)
data4.to_csv(r'C:\Users\GREEN\data\total\data4.csv', sep=',',encoding='cp949',index=False)
data5.to_csv(r'C:\Users\GREEN\data\total\data5.csv', sep=',',encoding='cp949',index=False)
data6.to_csv(r'C:\Users\GREEN\data\total\data6.csv', sep=',',encoding='cp949',index=False)

# %%
# data5 = pd.read_csv('../data/노인복지요약/cp939/노인복지요약5.csv', encoding='cp949')
# data5 = data5.dropna(subset = ['Unnamed: 1'])
# data5.to_csv(r'C:\Users\GREEN\data\total\data5.csv', sep=',',encoding='cp949')

# %%
# txt6 = pd.read_csv('../data/노인복지요약/txt6.txt', encoding='cp949')
