# %%
import pandas as pd
import numpy as np

# %%
data1 = pd.read_csv('../data/school/csv_school/school1.csv', encoding='cp949')
data2 = pd.read_csv('../data/school/csv_school/school2.csv', encoding='cp949')
data3 = pd.read_csv('../data/school/csv_school/school3.csv', encoding='cp949')
data4 = pd.read_csv('../data/school/csv_school/school4.csv', encoding='cp949')
data5 = pd.read_csv('../data/school/csv_school/school5.csv', encoding='cp949')
data6 = pd.read_csv('../data/school/csv_school/school6.csv', encoding='cp949')
data7 = pd.read_csv('../data/school/csv_school/school7.csv', encoding='cp949')
data8 = pd.read_csv('../data/school/csv_school/school8.csv', encoding='cp949')
data9 = pd.read_csv('../data/school/csv_school/school9.csv', encoding='cp949')
data10 = pd.read_csv('../data/school/csv_school/school10.csv', encoding='cp949')
data11 = pd.read_csv('../data/school/csv_school/school11.csv', encoding='cp949')
data12 = pd.read_csv('../data/school/csv_school/school12.csv', encoding='cp949')
data13 = pd.read_csv('../data/school/csv_school/school13.csv', encoding='cp949')
data14 = pd.read_csv('../data/school/csv_school/school14.csv', encoding='cp949')
data15 = pd.read_csv('../data/school/csv_school/school15.csv', encoding='cp949')
data16 = pd.read_csv('../data/school/csv_school/school16.csv', encoding='cp949')

# %%
data = pd.concat([data1,data2,data3,data4,data5,data6,data7,data8,data9,data10,data11,data12,data13,data14,data15,data16])

# %%
data
# Out:
#     시도교육청        폐교명    폐교년도 지역교육청 급별  활용현황                           주소
# 0      부산   가락초해포분교장  2004.0    북부  초  자체활용       부산광역시 강서구 봉림동 738-1714
# 1      부산        감정초  2019.0    서부  초  자체활용           부산광역시 사하구 감천동 10-2
# 2      부산      경남여자중  2009.0    남부  중  자체활용          부산광역시 동구 수정5동 563-1
# 3      부산   기장중철마분교장  1993.0   해운대  중  자체활용        부산광역시 기장군 철마면 연구리 594
# 4      부산      낙동여자중  1998.0    북부  중  자체활용         부산광역시 강서구 대저1동 421-3
# 5      부산        눌차초  2011.0    북부  초   미활용            부산광역시 강서구 눌차동 587
# 6      부산        다대초  2007.0    서부  초  자체활용         부산광역시 사하구 다대동 1140-1
# 7      부산        덕도초  2019.0    북부  초   미활용         부산광역시 강서구 강동동 2273-1
# 8      부산        동삼중  2019.0    서부  중  자체활용         부산광역시 영도구 동삼동 331-41
# 9      부산       디자인고  2010.0    남부  고  자체활용            부산광역시 동구 초량동 1167
# 10     부산        명지초  2016.0    북부  초  자체활용           부산광역시 강서구 명지동 1336
# 11     부산      부산개성중  2005.0    남부  중  자체활용       부산광역시 부산진구 부전2동 389-25
# ...

# %%
data.to_csv(r'C:\Users\GREEN\data\school\data.csv', sep=',',encoding='cp949',index=False)
