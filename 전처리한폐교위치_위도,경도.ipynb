# %%
import numpy as np
import pandas as pd
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import os
import googlemaps
import folium

# %%
school_loc = pd.read_csv('../data/폐교관련_인구데이터.csv',encoding = 'cp949')

# %%
gmaps_key = 'AIzaSyAK8Ow0bPCO0Vtse5l9dUeNRqjIrp0hiYU'
gmaps = googlemaps.Client(key = gmaps_key)

# %%
type(school_loc)
# Out:
# pandas.core.frame.DataFrame

# %%
school_loc['주소'][2]
# Out:
# '부산광역시 강서구 천성동 813'

# %%
location=gmaps.geocode(school_loc['주소'][394],language='ko')

# %%
location
# Out:
# [{'address_components': [{'long_name': '１３５',
#     'short_name': '１３５',
#     'types': ['premise']},
#    {'long_name': '신창리',
#     'short_name': '신창리',
#     'types': ['political', 'sublocality', 'sublocality_level_3']},
#    {'long_name': '한경면',
#     'short_name': '한경면',
#     'types': ['political', 'sublocality', 'sublocality_level_2']},
#    {'long_name': '제주시',
#     'short_name': '제주시',
#     'types': ['locality', 'political']},
#    {'long_name': '제주특별자치도',
#     'short_name': '제주특별자치도',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': '대한민국',
#     'short_name': 'KR',
#     'types': ['country', 'political']},
#    {'long_name': '695-940',
#     'short_name': '695-940',
#     'types': ['postal_code']}],
#   'formatted_address': '대한민국 제주특별자치도 제주시 한경면 신창리 135',
#   'geometry': {'location': {'lat': 33.3477089, 'lng': 126.1850354},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 33.3490578802915,
# ...

# %%
lat = location[0]['geometry']['location']['lat']
lng = location[0]['geometry']['location']['lng']
print(lat, lng)
# Out:
# 35.0688817 128.8411068

# %%
lat = location[0]['geometry']['location']['lat']
lng = location[0]['geometry']['location']['lng']
print(lat, lng)
# Out:
# 35.00345739999999 128.8310345

# %%
arr = np.arange(0,395)

# %%
df_lat = []
for num in arr:   
    location = gmaps.geocode(school_loc['주소'][num], language='ko')
    lat = location[0]['geometry']['location']['lat']
    df_lat.append(lat)

# %%
df_lat
# Out:
# [35.0688817,
#  35.00345739999999,
#  35.031595,
#  35.2144926,
#  35.1815986,
#  35.0552935,
#  35.6701341,
#  37.7704321,
#  37.6035228,
#  37.5273686,
#  37.718577,
#  37.676569,
#  37.676569,
#  36.4053001,
#  35.686006,
#  35.4394789,
#  36.4666136,
#  37.10092900000001,
#  37.8102323,
#  37.7765321,
#  37.20241650000001,
#  37.3980906,
#  37.9137075,
#  37.9246947,
#  37.1710576,
#  37.7048829,
#  37.7946862,
#  38.0543052,
#  37.284927,
#  37.6517124,
#  38.116174,
#  37.6672988,
#  37.2244672,
#  37.3199489,
#  37.97759569999999,
#  38.0282545,
#  37.34804159999999,
#  37.2572179,
#  37.2077982,
#  37.2771775,
#  37.2602026,
#  37.3965161,
#  37.3818445,
#  37.5278069,
#  37.1536891,
#  37.7096868,
#  37.9882814,
#  37.477872,
#  37.4418473,
#  37.4056625,
#  37.827806,
#  37.5667542,
#  37.2198632,
#  37.118846,
#  37.2311203,
#  37.2897228,
#  37.2311203,
#  37.1989792,
#  37.55879669999999,
#  37.5914713,
#  37.3223514,
#  37.3269478,
#  37.37976889999999,
#  37.2940174,
# ...

# %%
df_lng = []
for num in arr:
    location = gmaps.geocode(school_loc['주소'][num], language='ko')
    lng = location[0]['geometry']['location']['lng']
    df_lng.append(lng)

# %%
df_lng
# Out:
# [128.8411068,
#  128.8310345,
#  128.8133089,
#  128.9352088,
#  128.9782813,
#  128.8047273,
#  128.454797,
#  126.2391837,
#  126.489544,
#  126.4525008,
#  126.2321508,
#  126.1746742,
#  126.1746742,
#  127.4742927,
#  129.1645621,
#  129.2277516,
#  127.2816256,
#  127.2913047,
#  126.9289713,
#  126.9077538,
#  127.4483502,
#  127.679035,
#  127.5896846,
#  127.4907425,
#  126.6224067,
#  127.4481826,
#  127.0109724,
#  127.2724834,
#  127.1407046,
#  127.2861319,
#  127.2943007,
#  129.0416628,
#  127.8635287,
#  129.2193943,
#  128.055184,
#  128.0765088,
#  129.1633808,
#  129.1783293,
#  129.0780875,
#  129.0622637,
#  129.1117727,
#  129.0855407,
#  129.0942055,
#  128.3352339,
#  127.7867832,
#  127.7998743,
#  127.8482031,
#  127.8135633,
#  129.1143734,
#  128.131836,
#  128.6553172,
#  128.431552,
#  129.3186944,
#  129.2615478,
#  128.2787635,
#  128.2391986,
#  128.2787635,
#  128.6145417,
#  128.5627747,
#  128.2193204,
#  128.3355523,
#  128.3694741,
# ...

# %%
df_lat = pd.DataFrame(df_lat, columns=['lat'])

# %%
df_lng = pd.DataFrame(df_lng, columns=['lng'])
df_lng
# Out:
#             lng
# 0    128.841107
# 1    128.831034
# 2    128.813309
# 3    128.935209
# 4    128.978281
# 5    128.804727
# 6    128.454797
# 7    126.239184
# 8    126.489544
# 9    126.452501
# 10   126.232151
# 11   126.174674
# 12   126.174674
# 13   127.474293
# 14   129.164562
# 15   129.227752
# 16   127.281626
# 17   127.291305
# 18   126.928971
# 19   126.907754
# 20   127.448350
# 21   127.679035
# 22   127.589685
# 23   127.490742
# 24   126.622407
# 25   127.448183
# 26   127.010972
# 27   127.272483
# 28   127.140705
# 29   127.286132
# ..          ...
# 365  128.694807
# 366  127.784429
# 367  128.160970
# 368  127.948268
# 369  128.836532
# 370  128.821573
# 371  128.095065
# 372  128.407721
# 373  127.912230
# 374  128.370620
# 375  128.125174
# 376  128.558923
# 377  127.993992
# 378  128.696184
# 379  128.179175
# 380  128.617836
# 381  128.812254
# 382  128.479858
# 383  128.458611
# 384  128.494117
# 385  128.505290
# 386  127.689341
# 387  128.876174
# ...

# %%
df_loc = pd.concat([df_lat,df_lng], axis=1)

# %%
df_loc
# Out:
#            lat         lng
# 0    35.068882  128.841107
# 1    35.003457  128.831034
# 2    35.031595  128.813309
# 3    35.214493  128.935209
# 4    35.181599  128.978281
# 5    35.055293  128.804727
# 6    35.670134  128.454797
# 7    37.770432  126.239184
# 8    37.603523  126.489544
# 9    37.527369  126.452501
# 10   37.718577  126.232151
# 11   37.676569  126.174674
# 12   37.676569  126.174674
# 13   36.405300  127.474293
# 14   35.686006  129.164562
# 15   35.439479  129.227752
# 16   36.466614  127.281626
# 17   37.100929  127.291305
# 18   37.810232  126.928971
# 19   37.776532  126.907754
# 20   37.202417  127.448350
# 21   37.398091  127.679035
# 22   37.913708  127.589685
# 23   37.924695  127.490742
# 24   37.171058  126.622407
# 25   37.704883  127.448183
# 26   37.794686  127.010972
# 27   38.054305  127.272483
# 28   37.284927  127.140705
# 29   37.651712  127.286132
# ..         ...         ...
# 365  34.972509  128.694807
# 366  35.082299  127.784429
# ...

# %%
loc = pd.concat([school_loc,df_loc], axis=1)

# %%
loc.to_csv(r'C:\Users\GREEN\data\폐교_인구_위도경도.csv', sep=',',encoding='cp949',index=False)
